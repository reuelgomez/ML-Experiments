# %% [markdown]
# # ML-Exp 2: Implementation of an End-to-End Machine Learning Data Pipeline.

# %% [markdown]
# ## Student Name: REUEL ROLLAND GOMES
# ## Roll No.: 23 Batch: 1 Date: 21-01-2026

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\reuel\desktop\ml-semiv\lib\site-packages (2.4.1)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\reuel\desktop\ml-semiv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\reuel\desktop\ml-semiv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\reuel\desktop\ml-semiv\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\reuel\desktop\ml-semiv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from seaborn) (2.4.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\reuel\desktop\ml-semiv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import seaborn as sns
titanic_data=sns.load_dataset('titanic')

# %%
print (titanic_data.shape)
# Out:
# (891, 15)

# %%
print (titanic_data.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
print (titanic_data.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print (titanic_data.tail())
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
print (titanic_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# None

# %%
print (titanic_data.describe())
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
missing_values=titanic_data.isnull().sum()
print(missing_values)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
new_titanic_df=titanic_data.drop(columns=['deck'])

# %%
new_titanic_df['age'].fillna(new_titanic_df['age'].median(), inplace=True)
# Out:
# C:\Users\reuel\AppData\Local\Temp\ipykernel_15724\3025612607.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_titanic_df['age'].fillna(new_titanic_df['age'].median(), inplace=True)

# %%
missing_values=new_titanic_df.isnull().sum()
print(missing_values)
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
data=new_titanic_df
data['embark_town'].dtype
# Out:
# dtype('O')

# %%
data['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
data['embark_town'].fillna(data['embark_town'].mode()[0], inplace=True)
# Out:
# C:\Users\reuel\AppData\Local\Temp\ipykernel_15724\2719678445.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['embark_town'].fillna(data['embark_town'].mode()[0], inplace=True)

# %%
missing_values=data.isnull().sum()
print(missing_values)
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
fd=data
fd['embarked'].dtype
# Out:
# dtype('O')

# %%
fd['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
fd['embarked'].fillna(data['embarked'].mode()[0], inplace=True)
# Out:
# C:\Users\reuel\AppData\Local\Temp\ipykernel_15724\2655440061.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fd['embarked'].fillna(data['embarked'].mode()[0], inplace=True)

# %%
missing_values=fd.isnull().sum()
print(missing_values)
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
# Outlier detection - 'Age'
mean_age = np.mean(fd['age']) # calculates the mean
std_dev_age = np.std(fd['age']) # calculates the standard deviation
Z_scores_age = (fd['age'] - mean_age) / std_dev_age # computes the Z-scores
outliers_age = fd['age'][np.abs(Z_scores_age) > 3] # finds all the data points that are 3 standard deviations away from the mean
print("Outliers in 'Age' using Z-score: \n", outliers_age)

# Outlier detection - 'Fare'
mean_fare = np.mean(fd['fare']) # calculates the mean
std_dev_fare = np.std(fd['fare']) # calculates the standard deviation
Z_scores_fare = (fd['fare'] - mean_fare) / std_dev_fare # computes the Z-scores
outliers_fare = fd['fare'][np.abs(Z_scores_fare) > 3] # finds all the data points that are 3 standard deviations away from the mean
print("\nOutliers in 'Fare' using Z-score: \n", outliers_fare)
# Out:
# Outliers in 'Age' using Z-score:
#  96     71.0
# 116    70.5
# 493    71.0
# 630    80.0
# 672    70.0
# 745    70.0
# 851    74.0
# Name: age, dtype: float64
#
# Outliers in 'Fare' using Z-score:
#  27     263.0000
# 88     263.0000
# 118    247.5208
# 258    512.3292
# 299    247.5208
# 311    262.3750
# 341    263.0000
# 377    211.5000
# 380    227.5250
# 438    263.0000
# 527    221.7792
# 557    227.5250
# 679    512.3292
# 689    211.3375
# 700    227.5250
# 716    227.5250
# 730    211.3375
# 737    512.3292
# 742    262.3750
# 779    211.3375
# Name: fare, dtype: float64

# %%
# Drop rows with missing 'age' values
fd = fd.dropna(subset=['age'])

# Calculate the upper bound for 'age'
Q1 = fd['age'].quantile(0.25)
Q3 = fd['age'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR

# Cap the outliers for 'age'
fd['age'] = np.where(fd['age'] > upper_bound, upper_bound, fd['age'])

# Calculate the upper bound for 'fare'
Q1 = fd['fare'].quantile(0.25)
Q3 = fd['fare'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR

# Cap the outliers for 'fare'
fd['fare'] = np.where(fd['fare'] > upper_bound, upper_bound, fd['fare'])

# %%
# Using 'survived' instead
counts = fd['survived'].value_counts()

plt.pie(counts, labels=['Died', 'Survived'], autopct='%1.1f%%', colors=['tomato', 'lightgreen'])
plt.title('Survival Proportions')
plt.show()

# %%
# Plotting the 'fare' column
plt.hist(fd['fare'], bins=30, color='teal', edgecolor='black')

plt.title('Distribution of Ticket Fares')
plt.xlabel('Fare')
plt.ylabel('Number of Passengers')
plt.grid(axis='y', alpha=0.75)

plt.show()

# %%
plt.scatter(fd['age'], fd['fare'], alpha=0.5, c='purple')

plt.title('Age vs. Ticket Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
le=LabelEncoder()
fd['sex']=le.fit_transform(fd['sex'])
fd['embarked']=le.fit_transform(fd['embarked'])

# %%
fd.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500         2  Third    man
# 1         1       1    0  38.0      1      0  65.6344         0  First  woman
# 2         1       3    0  26.0      0      0   7.9250         2  Third  woman
# 3         1       1    0  35.0      1      0  53.1000         2  First  woman
# 4         0       3    1  35.0      0      0   8.0500         2  Third    man
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False
# 1       False    Cherbourg   yes  False
# 2       False  Southampton   yes   True
# 3       False  Southampton   yes  False
# 4        True  Southampton    no   True

# %%
fd=fd[['pclass','sex','age','fare','embarked','survived']]
x=fd[['pclass','sex','age','fare','embarked',]]
y=fd['survived']

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.3, random_state=42)

# %%
fd.head()
# Out:
#    pclass  sex   age     fare  embarked  survived
# 0       3    1  22.0   7.2500         2         0
# 1       1    0  38.0  65.6344         0         1
# 2       3    0  26.0   7.9250         2         1
# 3       1    0  35.0  53.1000         2         1
# 4       3    1  35.0   8.0500         2         0

# %%
model=LogisticRegression(max_iter=1000)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred=model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7947761194029851

# %%
new_passenger=pd.DataFrame({
    'pclass':[3],
    'sex':['male'], 
    'age':[28], 
    'fare':[7.25], 
    'embarked':['S']
})

# %%
new_passenger_encoded=pd.get_dummies(new_passenger)
new_passenger_encoded=new_passenger_encoded.reindex(columns=x.columns,fill_value=0)

# %%
prediction=model.predict(new_passenger_encoded)
print(f"Survived" if prediction[0]==1 else "Not Survived")
# Out:
# Survived

# %%
new_passenger=pd.DataFrame({
    'pclass':[1,2,3],
    'sex':['female','male','female'], 
    'age':[38,45,14], 
    'fare':[80.0,8.05,20.0], 
    'embarked':['C','S','Q']
})

new_passenger_encoded=pd.get_dummies(new_passenger)
new_passenger_encoded=new_passenger_encoded.reindex(columns=x.columns,fill_value=0)

# %%
prediction=model.predict(new_passenger_encoded)
for i,pred in enumerate(prediction):
    print(f"Survived {i+1}:", "Survived" if pred==1 else "Not Survived")
# Out:
# Survived 1: Survived
# Survived 2: Survived
# Survived 3: Survived
